# %% [markdown]
# # Decision trees for regression

# %%
pip install six
# Out:
# Requirement already satisfied: six in c:\users\wkdwo\appdata\roaming\python\python311\site-packages (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
import sys
sys.path.append(r'C:\Users\wkdwo\OneDrive\바탕 화면\깃허브\code\code2\Chapter_09_Decision_Trees\utils.py')
import utils
import matplotlib.pyplot as plt
import six

# %%
features = [[10],[20],[30],[40],[50],[60],[70],[80]]
labels = [7,5,7,1,2,1,5,4]

# %%
plt.scatter(features, labels)
plt.xlabel("Age")
plt.ylabel("Days per week")
plt.show()

# %%
dt_regressor = DecisionTreeRegressor(max_depth=2)
dt_regressor.fit(features, labels)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
utils.display_tree(dt_regressor)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 utils.display_tree(dt_regressor)
#
# File c:\Users\wkdwo\OneDrive\바탕 화면\깃허브\code\code2\Chapter_09_Decision_Trees\utils.py:43, in display_tree(dt)
#      42 def display_tree(dt):
# ---> 43     from sklearn.externals.six import StringIO
#      44     import six
#      45     from IPython.display import Image
#
# ModuleNotFoundError: No module named 'sklearn.externals.six'

# %%
utils.plot_regressor(dt_regressor, features, labels)

# %% [markdown]
# # Finding the first split by mimizing the MSE

# %%
for i in range(0,9):
    left = np.array(labels[:i])
    right = np.array(labels[i:])
    print("*****")
    print(left, right)
    print(np.mean(left), np.mean(right))
    left_tse = left-np.mean(left)
    right_tse = right-np.mean(right)
    print(1/8*(np.dot(left_tse, left_tse) + np.dot(right_tse, right_tse)))
# Out:
# *****
# [] [7 5 7 1 2 1 5 4]
# nan 4.0
# 5.25
# *****
# [7] [5 7 1 2 1 5 4]
# 7.0 3.5714285714285716
# 3.9642857142857144
# *****
# [7 5] [7 1 2 1 5 4]
# 6.0 3.3333333333333335
# 3.916666666666667
# *****
# [7 5 7] [1 2 1 5 4]
# 6.333333333333333 2.6
# 1.9833333333333334
# *****
# [7 5 7 1] [2 1 5 4]
# 5.0 3.0
# 4.25
# *****
# [7 5 7 1 2] [1 5 4]
# 4.4 3.3333333333333335
# 4.983333333333333
# *****
# [7 5 7 1 2 1] [5 4]
# 3.8333333333333335 4.5
# 5.166666666666667
# *****
# [7 5 7 1 2 1 5] [4]
# 4.0 4.0
# 5.25
# *****
# [7 5 7 1 2 1 5 4] []
# 4.0 nan
# 5.25
# c:\Users\wkdwo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\wkdwo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
1/8*(
    (7-3.833)**2 +
    (5-3.833)**2 +
    (7-3.833)**2 +
    (1-3.833)**2 +
    (2-3.833)**2 +
    (1-3.833)**2 +
    (5-4.5)**2 +
    (4-4.5)**2)
# Out:
# 5.16666675

# %%
np.array([7,5,7,1,2,1,5,4]).mean()
# Out:
# np.float64(4.0)
